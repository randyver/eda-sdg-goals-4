# %%
import pandas as pd

# %%
df = pd.read_excel("4.5.xlsx")

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Goal, Target, Indicator, SeriesCode, SeriesDescription, GeoAreaCode, GeoAreaName, Education level, Reporting Type, Type of skill, Units, 2000, 2001, 2003, 2006, 2007, 2009, 2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2021]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_indo = df[df['GeoAreaName'] == 'China, Hong Kong Special Administrative Region']

# %%
df_indo
# Out:
#     Goal  Target Indicator   SeriesCode  \
# 68     4     4.5     4.5.1  SE_TOT_RUPI
# 69     4     4.5     4.5.1  SE_TOT_RUPI
# 70     4     4.5     4.5.1  SE_TOT_RUPI
# 71     4     4.5     4.5.1  SE_TOT_RUPI
#
#                                     SeriesDescription  GeoAreaCode  \
# 68  Adjusted rural to urban parity index for achie...          344
# 69  Adjusted rural to urban parity index for achie...          344
# 70  Adjusted rural to urban parity index for achie...          344
# 71  Adjusted rural to urban parity index for achie...          344
#
#                                        GeoAreaName Education level  \
# 68  China, Hong Kong Special Administrative Region          LOWSEC
# 69  China, Hong Kong Special Administrative Region          LOWSEC
# 70  China, Hong Kong Special Administrative Region          PRIMAR
# 71  China, Hong Kong Special Administrative Region          PRIMAR
#
#    Reporting Type Type of skill  ... 2009  2011  2012  2013     2015  2016  \
# ...

# %%
df_indo.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Education level', 'Reporting Type',
#        'Type of skill', 'Units', '2000', '2001', '2003', '2006', '2007',
#        '2009', '2011', '2012', '2013', '2015', '2016', '2017', '2018', '2019',
#        '2021'],
#       dtype='object')

# %%
df_indo.drop(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription', 'GeoAreaCode', 'GeoAreaName', 'Reporting Type'], axis = 1,inplace= True)
# Out:
# C:\Users\Randy Verdian\AppData\Local\Temp\ipykernel_16440\1323960795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_indo.drop(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription', 'GeoAreaCode', 'GeoAreaName', 'Reporting Type'], axis = 1,inplace= True)

# %%
df_indo
# Out:
#    Education level Type of skill  Units     2000  2001  2003     2006  2007  \
# 68          LOWSEC    SKILL_MATH  Ratio  0.78513   NaN   NaN      NaN   NaN
# 69          LOWSEC    SKILL_READ  Ratio  0.69464   NaN   NaN      NaN   NaN
# 70          PRIMAR    SKILL_MATH  Ratio      NaN   NaN   NaN      NaN   NaN
# 71          PRIMAR    SKILL_READ  Ratio      NaN   NaN   NaN  0.98695   NaN
#
#     2009  2011  2012  2013     2015  2016  2017  2018  2019  2021
# 68   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 69   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 70   NaN   NaN   NaN   NaN  1.01417   NaN   NaN   NaN   NaN   NaN
# 71   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN

# %%
df_indo.drop('Units', axis=1, inplace= True)
# Out:
# C:\Users\Randy Verdian\AppData\Local\Temp\ipykernel_16440\3055401132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_indo.drop('Units', axis=1, inplace= True)

# %%
df_indo
# Out:
#    Education level Type of skill     2000  2001  2003     2006  2007  2009  \
# 68          LOWSEC    SKILL_MATH  0.78513   NaN   NaN      NaN   NaN   NaN
# 69          LOWSEC    SKILL_READ  0.69464   NaN   NaN      NaN   NaN   NaN
# 70          PRIMAR    SKILL_MATH      NaN   NaN   NaN      NaN   NaN   NaN
# 71          PRIMAR    SKILL_READ      NaN   NaN   NaN  0.98695   NaN   NaN
#
#     2011  2012  2013     2015  2016  2017  2018  2019  2021
# 68   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 69   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 70   NaN   NaN   NaN  1.01417   NaN   NaN   NaN   NaN   NaN
# 71   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN

# %%
df_indo.drop(['2001','2007','2013','2016','2017','2019','2021'], axis= 1,inplace=True)
# Out:
# C:\Users\Randy Verdian\AppData\Local\Temp\ipykernel_16440\391733512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_indo.drop(['2001','2007','2013','2016','2017','2019','2021'], axis= 1,inplace=True)

# %%
df_indo
# Out:
#    Education level Type of skill     2000  2003     2006  2009  2011  2012  \
# 68          LOWSEC    SKILL_MATH  0.78513   NaN      NaN   NaN   NaN   NaN
# 69          LOWSEC    SKILL_READ  0.69464   NaN      NaN   NaN   NaN   NaN
# 70          PRIMAR    SKILL_MATH      NaN   NaN      NaN   NaN   NaN   NaN
# 71          PRIMAR    SKILL_READ      NaN   NaN  0.98695   NaN   NaN   NaN
#
#        2015  2018
# 68      NaN   NaN
# 69      NaN   NaN
# 70  1.01417   NaN
# 71      NaN   NaN

# %%
import matplotlib.pyplot as plt
import seaborn as  sns
df_long = pd.melt(df_indo, id_vars=["Education level", "Type of skill"], 
                  var_name="Year", value_name="Value")


df_long["Year"] = pd.to_numeric(df_long["Year"])


plt.figure(figsize=(10, 6))
sns.lineplot(data=df_long, x="Year", y="Value", hue="Type of skill", style="Education level", markers=True)
plt.title("Skill Progression by Education Level (2000-2018)")
plt.ylabel("Value")
plt.xlabel("Year")
plt.xticks(df_long["Year"].unique())  
plt.show()

# %% [markdown]
# Dari visualisasi di atas artinya seiring majunya tahun rasio tingkat kemahiran minimum di bidang membaca dan matematika menurun yang artinya pendidikan di perkotaan maju(menjadi lebih baik) lebih signifikan dari pada pendidikan di desa. rasio pada tahun 2018 juga terlihat sangat rendah yaitu sekitar 0.3-0.4 yang artinya capaian tingkat kemahiran minimum di bidang membaca dan matematika di desa sangat jauh di bawah capaian tingkat kemahiran minimum di bidang membaca dan matematika di kota.
