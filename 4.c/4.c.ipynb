# %% [markdown]
# ## 4.c dataset
# proporsi guru dengan kualifikasi minimum yang diperlukan

# %%
import pandas as pd

df = pd.read_excel('4.c.xlsx')
df.head()
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     4    4.c     4.c.1  SE_TRA_GRDL
# 1     4    4.c     4.c.1  SE_TRA_GRDL
# 2     4    4.c     4.c.1  SE_TRA_GRDL
# 3     4    4.c     4.c.1  SE_TRA_GRDL
# 4     4    4.c     4.c.1  SE_TRA_GRDL
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Proportion of teachers with the minimum requir...            8     Albania
# 1  Proportion of teachers with the minimum requir...            8     Albania
# 2  Proportion of teachers with the minimum requir...            8     Albania
# 3  Proportion of teachers with the minimum requir...            8     Albania
# 4  Proportion of teachers with the minimum requir...            8     Albania
#
#   Education level Reporting Type      Sex  ... 2014  2015  2016  2017  \
# 0          LOWSEC              G  BOTHSEX  ...  NaN   NaN   NaN   NaN
# 1          LOWSEC              G   FEMALE  ...  NaN   NaN   NaN   NaN
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    2302
# Name: count, dtype: int64

# %% [markdown]
# there is no duplicated data

# %%
df_indo = df[df['GeoAreaName'] == "China, Hong Kong Special Administrative Region"]
df_indo
# Out:
#      Goal Target Indicator   SeriesCode  \
# 445     4    4.c     4.c.1  SE_TRA_GRDL
# 446     4    4.c     4.c.1  SE_TRA_GRDL
# 447     4    4.c     4.c.1  SE_TRA_GRDL
# 448     4    4.c     4.c.1  SE_TRA_GRDL
# 449     4    4.c     4.c.1  SE_TRA_GRDL
# 450     4    4.c     4.c.1  SE_TRA_GRDL
# 451     4    4.c     4.c.1  SE_TRA_GRDL
# 452     4    4.c     4.c.1  SE_TRA_GRDL
# 453     4    4.c     4.c.1  SE_TRA_GRDL
#
#                                      SeriesDescription  GeoAreaCode  \
# 445  Proportion of teachers with the minimum requir...          344
# 446  Proportion of teachers with the minimum requir...          344
# 447  Proportion of teachers with the minimum requir...          344
# 448  Proportion of teachers with the minimum requir...          344
# 449  Proportion of teachers with the minimum requir...          344
# 450  Proportion of teachers with the minimum requir...          344
# 451  Proportion of teachers with the minimum requir...          344
# ...

# %%
# Pilih kolom dari tahun 2005 hingga 2023
df_indo_time = df_indo.loc[:, '2005':'2023']

# %%
df_indo_time
# Out:
#          2005      2006      2007      2008      2009      2010      2011  \
# 445  92.45601       NaN  95.85901  96.33993  95.76323  95.07105  94.97800
# 446  92.74693       NaN  96.06720  96.62834  95.98160  95.39157  95.36212
# 447  56.71642       NaN  70.93023  64.51613  70.93023  64.07767  63.49206
# 448  93.16417  94.83207  94.56024  95.11988  95.12415  95.60564  95.79129
# 449  93.29731  95.10364  94.89630  95.42334  95.56034  95.94760  96.06299
# 450  92.68475  93.86213  93.38005  94.05105  93.58725  94.38937  94.82096
# 451  92.89728  95.02652  94.30875  93.98363  93.31926  94.16552  94.56663
# 452  93.24780       NaN  94.60594  94.18736  93.56118  94.26990  94.67856
# 453  92.45205       NaN  93.92782  93.72070  93.00418  94.02758  94.41755
#
#          2012      2013      2014      2015      2016      2017      2018  \
# 445  94.91817  95.07489  94.77552  95.59451  95.35124  96.15219  96.48887
# 446  95.21150  95.36775  95.11955  95.97130  95.78481  96.53708  96.81051
# ...

# %%
df_indo['SeriesDescription'].value_counts()
# Out:
# SeriesDescription
# Proportion of teachers with the minimum required qualifications, by education level and sex (%)    9
# Name: count, dtype: int64

# %%
df_indo_filtered = df_indo[['Education level', 'Sex', '2022']]
df_indo_filtered
# Out:
#     Education level      Sex      2022
# 445          PREPRI  BOTHSEX  97.52336
# 446          PREPRI   FEMALE  97.89418
# 447          PREPRI     MALE  82.83133
# 448          PRIMAR  BOTHSEX  95.67468
# 449          PRIMAR   FEMALE  96.04396
# 450          PRIMAR     MALE  94.47835
# 451          SECOND  BOTHSEX  93.30408
# 452          SECOND   FEMALE  94.29089
# 453          SECOND     MALE  92.06134

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Misalkan dataframe Anda bernama df
sns.barplot(x="Education level", y="2022", hue="Sex", data=df_indo_filtered)
plt.title("2022 Values per Education Level and Sex")
plt.show()

# %% [markdown]
# Untuk masing-masing tingkat edukasi

# %%
df_CHK = df[df['GeoAreaName'] == "China, Hong Kong Special Administrative Region"]

# %%
df_CHK
# Out:
#      Goal Target Indicator   SeriesCode  \
# 445     4    4.c     4.c.1  SE_TRA_GRDL
# 446     4    4.c     4.c.1  SE_TRA_GRDL
# 447     4    4.c     4.c.1  SE_TRA_GRDL
# 448     4    4.c     4.c.1  SE_TRA_GRDL
# 449     4    4.c     4.c.1  SE_TRA_GRDL
# 450     4    4.c     4.c.1  SE_TRA_GRDL
# 451     4    4.c     4.c.1  SE_TRA_GRDL
# 452     4    4.c     4.c.1  SE_TRA_GRDL
# 453     4    4.c     4.c.1  SE_TRA_GRDL
#
#                                      SeriesDescription  GeoAreaCode  \
# 445  Proportion of teachers with the minimum requir...          344
# 446  Proportion of teachers with the minimum requir...          344
# 447  Proportion of teachers with the minimum requir...          344
# 448  Proportion of teachers with the minimum requir...          344
# 449  Proportion of teachers with the minimum requir...          344
# 450  Proportion of teachers with the minimum requir...          344
# 451  Proportion of teachers with the minimum requir...          344
# ...

# %% [markdown]
# Kita akan membandingkan dengan proporsi pada china(hong kong)

# %%
df_CHK_filtered = df_CHK[['Education level', 'Sex', '2022']]
df_CHK_filtered
# Out:
#     Education level      Sex      2022
# 445          PREPRI  BOTHSEX  97.52336
# 446          PREPRI   FEMALE  97.89418
# 447          PREPRI     MALE  82.83133
# 448          PRIMAR  BOTHSEX  95.67468
# 449          PRIMAR   FEMALE  96.04396
# 450          PRIMAR     MALE  94.47835
# 451          SECOND  BOTHSEX  93.30408
# 452          SECOND   FEMALE  94.29089
# 453          SECOND     MALE  92.06134

# %%
sns.barplot(x="Education level", y="2022", hue="Sex", data=df_CHK_filtered)
plt.title("2022 Values per Education Level and Sex")

plt.show()

# %% [markdown]
# Dari data proporsi tahun 2022 saja terlihat negara maju seperti china memiliki proporsi guru yang memenuhi kualifikasi minimum lebih banyak ketimbang di Indonesia
# selanjutnya akan dicari korelasi pengaruh proporsi guru yang memenuhi kualifikasi minimum dengan kualitas pendidikan di negara itu
