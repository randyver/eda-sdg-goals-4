# %%
# read data from xlsx
import pandas as pd

df = pd.read_csv('smp_total.csv')
df.head(50)
# Out:
#                            Provinsi  2021  2022  2023
# 0              Prov. D.K.I. Jakarta   336   272    78
# 1                  Prov. Jawa Barat  1618  1217  1881
# 2                 Prov. Jawa Tengah   621   464   692
# 3             Prov. D.I. Yogyakarta    16    14    22
# 4                  Prov. Jawa Timur  2438  1792  2878
# 5                        Prov. Aceh   376   440   597
# 6              Prov. Sumatera Utara  1284  1666  2039
# 7              Prov. Sumatera Barat   530   309   372
# 8                        Prov. Riau   483   498   350
# 9                       Prov. Jambi   241   160   182
# 10           Prov. Sumatera Selatan   441   524   585
# 11                    Prov. Lampung   291   199   280
# 12           Prov. Kalimantan Barat   422   384   651
# 13          Prov. Kalimantan Tengah   218   220   198
# 14         Prov. Kalimantan Selatan   248   183   183
# 15           Prov. Kalimantan Timur   132   184   193
# 16             Prov. Sulawesi Utara   244   181   219
# 17            Prov. Sulawesi Tengah   454   500   505
# 18           Prov. Sulawesi Selatan   765   717   880
# 19          Prov. Sulawesi Tenggara   235   230   259
# 20                     Prov. Maluku   152   211   246
# 21                       Prov. Bali    35    46    69
# 22        Prov. Nusa Tenggara Barat   577   319   443
# 23        Prov. Nusa Tenggara Timur   927   866   842
# 24                      Prov. Papua   554   856   214
# 25                   Prov. Bengkulu    89    91   160
# 26               Prov. Maluku Utara   193   144   177
# 27                     Prov. Banten   454   471   517
# 28  Prov. Kepulauan Bangka Belitung    47    31    40
# 29                  Prov. Gorontalo   167   183   183
# 30             Prov. Kepulauan Riau    29    19    38
# 31                Prov. Papua Barat   116   112   102
# 32             Prov. Sulawesi Barat   155   166   222
# 33           Prov. Kalimantan Utara    84    39    43
# 34                      Luar Negeri    70     8    11

# %%
import matplotlib.pyplot as plt


# Hitung total setiap tahun
total_per_tahun = df[['2021', '2022', '2023']].sum()

# Buat grafik line chart
plt.plot(total_per_tahun.index, total_per_tahun.values, marker='o')

# Tambahkan value eksak di setiap tahun dengan warna oranye
for i, value in enumerate(total_per_tahun.values):
    plt.text(total_per_tahun.index[i], value, f'{value:.0f}', ha='center', va='bottom', color='green')

# Judul dan label
plt.title('Total Angka Putus Sekolah Tingkat SMP')
plt.xlabel('Tahun')
plt.ylabel('Total')
plt.grid(True)

# Tampilkan grafik
plt.show()

# %%
# Membuat stacked bar chart untuk perbandingan jumlah setiap tahun per provinsi
df.set_index('Provinsi')[['2021', '2022', '2023']].plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Pertumbuhan Jumlah per Provinsi Angka Putus Sekolah Tingkat SMP (2021-2023)')
plt.xlabel('Provinsi')
plt.ylabel('Jumlah')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table


# Menyiapkan figure
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Daftar tahun yang akan dianalisis
years = ['2021', '2022', '2023']

# Membuat tabel untuk setiap tahun
for i, year in enumerate(years):
    # Mengurutkan data berdasarkan tahun dan memilih 5 provinsi dengan angka putus sekolah terbanyak
    top_provinces = df.nlargest(5, year)
    
    # Menampilkan tabel di subplot
    axes[i].axis('off')  # Menyembunyikan axis
    table_data = top_provinces[['Provinsi', year]].rename(columns={year: 'Angka Putus Sekolah'})
    table_plot = table(axes[i], table_data, loc='center', cellLoc='center', colWidths=[0.2, 0.2])
    
    # Menambahkan judul
    axes[i].set_title(f'5 Provinsi Terbesar {year}')

# Menambahkan judul umum
plt.suptitle('5 Provinsi Terbesar Berdasarkan Angka Putus Sekolah Tingkat SMP', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Menyesuaikan layout agar tidak overlap dengan judul

# Menampilkan plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table


# Menyiapkan figure
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Daftar tahun yang akan dianalisis
years = ['2021', '2022', '2023']

# Membuat tabel untuk setiap tahun
for i, year in enumerate(years):
    # Mengurutkan data berdasarkan tahun dan memilih 5 provinsi dengan angka putus sekolah terkecil
    smallest_provinces = df.nsmallest(5, year)
    
    # Menampilkan tabel di subplot
    axes[i].axis('off')  # Menyembunyikan axis
    table_data = smallest_provinces[['Provinsi', year]].rename(columns={year: 'Angka Putus Sekolah'})
    table_plot = table(axes[i], table_data, loc='center', cellLoc='center', colWidths=[0.2, 0.2])
    
    # Menambahkan judul
    axes[i].set_title(f'5 Provinsi Terkecil {year}')

# Menambahkan judul umum
plt.suptitle('5 Provinsi Terkecil Berdasarkan Angka Putus Sekolah Tingkat SMP', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Menyesuaikan layout agar tidak overlap dengan judul

# Menampilkan plot
plt.show()
